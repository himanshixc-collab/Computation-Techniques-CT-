# %% [markdown]
# #Assignment 2

# %%
#Total outcome when two dice are rolled
total_outcome = 6 * 6

# Outcome where both dice show the same number
same_faces = 6

# Probability
probability = same_faces / total_outcome

print("Total outcomes:", total_outcome)
print("Probability of getting both faces same:", probability)
# Out:
# Total outcomes: 36
# Probability of getting both faces same: 0.16666666666666666
